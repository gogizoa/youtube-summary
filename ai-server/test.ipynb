# %%
from youtube_transcript_api import YouTubeTranscriptApi
import google.generativeai as genai

# %%
from datetime import timedelta

video_id = "e0koWWAmXSk"

srt = YouTubeTranscriptApi.get_transcript(video_id, languages=['ko'])

for line in srt:
    # 시작 시간
    start_time = timedelta(seconds=int(line['start']))
    
    # 시간과 텍스트 출력
    print(f"[{start_time}] {line['text']}")
# Out:
# [0:00:00] 도커가 컨테이너 이전 시대에 살던
# [0:00:02] 개발자들은 그냥 원신과 다를 바가
# [0:00:04] 없었습니다 어디 새로 취업하면 개발
# [0:00:06] 환경 세팅을 맞추느라 하루 종일 삽질
# [0:00:08] 했었고요 개발환경 업데이트를 하면
# [0:00:10] 항상 뭐가 망가지기 때문에 그러지
# [0:00:12] 말라고 열심히 기도하기도 했고요
# [0:00:14] 그리고 내가 코드 짠 걸 서버
# [0:00:15] 컴퓨터에 보내서 실행만 하려고 하면
# [0:00:17] 컴퓨터가 에러나고 폭발하고 그런
# [0:00:19] 일들이 많아서 배포하기 전에 고사도
# [0:00:21] 지내고 그랬습니다 하지만 도커와
# [0:00:23] 컨테이너가 등장하고 나서이 짓거리가
# [0:00:25] 거의 없어졌고요 그래서 그런지
# [0:00:27] 개발자들이 가장 많이 쓰는 툴 1위를
# [0:00:29] 맨 도커가 차지하고 있고요 그리고 또
# [0:00:31] 요즘은 코딩 책을 보려고 해도 아니면
# [0:00:33] 인터넷에서 딥러닝 모델을 다운받아서
# [0:00:36] 돌리려고 해도 도커 명령어부터 보이는
# [0:00:38] 경우들이 많습니다 자 도커가 뭐냐면
# [0:00:40] 리누스 컨테이너를 기반으로 만든 OS
# [0:00:42] 레벨의 가상화 기술인데 이따고
# [0:00:44] 설명하면 다 뒤로 가기 누르니까 쉽게
# [0:00:46] 이해해 보도록 합시다 여러분들이
# [0:00:49] 코딩하다가 망해 가지고 서울에다 이제
# [0:00:51] 뭐 치킨집을 하나 차렸다고 칩시다
# [0:00:53] 근데 잘돼 가지고 이번에 부산에가면
# [0:00:55] 내고 싶은 거예요 그러면 부산 지점은
# [0:00:57] 어떻게 운영할 거예요 가장 쉽게 할
# [0:00:59] 수 있는게 에 내가 쓰던 레시피만
# [0:01:01] 보내서 이걸 그대로 따라하라고 하는
# ...

# %%
# Gemini API 키 설정
GOOGLE_API_KEY = "AIzaSyDbaaLsUkkPCIpd7KUkrsqhi6Whx9XzeOM"
genai.configure(api_key=GOOGLE_API_KEY)

# 비디오 ID로 자막 가져오기
video_id = "e0koWWAmXSk"
transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['ko'])
transcript_text = " ".join(line['text'] for line in transcript)

# Gemini 모델 설정
model = genai.GenerativeModel('gemini-1.5-flash')

# 요약 프롬프트
prompt = f"""
영상 내용을 다음 형식으로 요약해주세요:

각 내용은 반드시 한 줄로 작성하며, 중첩 구조나 하위 목록을 사용하지 않습니다.
모든 요점은 다음의 정확한 형식을 따릅니다:
* [이모지] **[주제/키워드]:** [한 줄로 된 설명 내용]

규칙:
- 주제/키워드는 명사형으로 끝나기
- 설명은 마침표로 종료
- 여러 개의 내용은 하위 목록이 아닌 별도의 한 줄로 작성
- 복잡한 내용도 하나의 간결한 문장으로 압축
- 각 항목마다 내용을 가장 잘 표현하는 서로 다른 이모지 사용
- 이모지는 해당 내용과 의미적으로 연관성이 있어야 함

예시:
* 🏗 **개발 환경 문제점:** 과거 개발자들의 어려움 설명.
* 📦 **밀키트 비유:** 도커는 코드와 환경을 포장해서 제공.
* 🚢 **컨테이너 개념:** 독립된 환경에서 애플리케이션 실행.
* 🔄 **자동화 기능:** 빌드부터 배포까지 자동화 지원.

영상 내용:
{transcript_text}
"""

# 요약 생성 및 출력
response = model.generate_content(prompt)
print(response.text)
# Out:
# * 👨‍💻 **개발 환경 설정의 어려움:** 과거 개발자들은 환경 설정에 많은 시간을 소비하고, 업데이트로 인한 문제 발생에 시달렸다.
# * 🐔 **밀키트 비유:** 도커는 애플리케이션과 실행 환경을 하나의 패키지로 제공하여 일관성을 유지한다.
# * 📦 **컨테이너 기술:** 도커는 OS 레벨 가상화를 통해 애플리케이션을 독립적인 환경에서 실행한다.
# * ✨ **도커의 인기:** 도커는 개발자들이 가장 많이 사용하는 툴 중 하나이며, 다양한 코딩 학습 자료에서 활용된다.
# * 🏗️ **MSA(마이크로서비스 아키텍처):** 도커를 통해 애플리케이션을 작은 단위로 나누어 배포 및 관리의 효율성을 높인다.
# * 🤖 **자동화된 배포:** 도커는 빌드, 테스트, 배포 과정을 자동화하여 개발 속도를 향상시킨다.
# * 🧹 **깨끗한 개발 환경:** 도커를 사용하면 원하는 프로그램과 버전을 쉽게 설치하고 제거하여 환경을 깔끔하게 유지한다.
# * 🐳 **도커의 기반 기술:** 도커는 리눅스 컨테이너 기술을 기반으로 하며, 가상 머신보다 가볍고 빠르다.
# * 🛠️ **도커라이즈:** 도커라이즈는 리눅스 컨테이너를 쉽게 생성하고 사용할 수 있도록 지원하는 도구이다.
# * ⚠️ **도커의 단점:** 보안 문제, 컨테이너 관리, 서버 비용 증가, 영구적인 데이터 저장의 어려움 등의 단점이 존재한다.
# * 👶 **초보자의 학습 곡선:** 도커를 너무 일찍 학습하면 실제 코딩 실력 향상에 방해될 수 있다.
# * 📚 **도커 학습 전략:** 도커를 효과적으로 활용하기 위해서는 기본적인 코딩 능력과 원리를 먼저 이해해야 한다.
# *  orchestrates **도커 컴포즈:** 도커 컴포즈는 여러 컨테이너를 관리하는 오케스트레이션 도구이다.
